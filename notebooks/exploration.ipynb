# %% [markdown]
# # Thumalien — Exploration
#
# Notebook d'exploration des données et des modèles.

# %%
import pandas as pd
from src.config import MODEL_NAME

print(f"Modèle configuré : {MODEL_NAME}")
